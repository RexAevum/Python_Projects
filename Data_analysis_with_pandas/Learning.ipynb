# %%
import pandas

# %%
df1 = pandas.read_csv("data\supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("data\supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df3 = pandas.read_excel("data\supermarkets.xlsx", sheet_name=0)# Implemented a work around using openpyxl due to changes done with newest version of python
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("data\supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("data\supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# If the file has no header line, to make sure the table is correct you need to state that the header = None
df6 = pandas.read_csv("data\supermarkets-commas.txt")
df6
# to set the names of columbs
df6.columns = ["ID", "Address", "City", "State", "County", "Names", "Employee NR"]
df6
# Out:
#    ID          Address           City             State County        Names  \
# 0   1     3666 21st St  San Francisco          CA 94114    USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119    USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114    USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114    USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California    USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114    USA   Richvalley
#
#    Employee NR
# 0            8
# 1           15
# 2           25
# 3           10
# 4           12
# 5           20

# %%
df7 = df6.set_index("ID", drop=False)
df7
# If you asign another columb to serve as index, then unless specified the old column, that served as 
# the index before gets removed from the table
# To prevent that, need to pass argument drop=False (true by default)
# Out:
#     ID          Address           City             State County        Names  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114    USA      Madeira
# 2    2   735 Dolores St  San Francisco          CA 94119    USA  Bready Shop
# 3    3      332 Hill St  San Francisco  California 94114    USA  Super River
# 4    4     3995 23rd St  San Francisco          CA 94114    USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco        California    USA      Sanchez
# 6    6  551 Alvarado St  San Francisco          CA 94114    USA   Richvalley
#
#     Employee NR
# ID
# 1             8
# 2            15
# 3            25
# 4            10
# 5            12
# 6            20

# %%
df8 = df7.set_index("State", inplace=False, drop=False)
df8
# Out:
#                           Address           City             State County  \
# State
# CA 94114             3666 21st St  San Francisco          CA 94114    USA
# CA 94119           735 Dolores St  San Francisco          CA 94119    USA
# California 94114      332 Hill St  San Francisco  California 94114    USA
# CA 94114             3995 23rd St  San Francisco          CA 94114    USA
# California        1056 Sanchez St  San Francisco        California    USA
# CA 94114          551 Alvarado St  San Francisco          CA 94114    USA
#
#                         Names  Employee NR
# State
# CA 94114              Madeira            8
# CA 94119          Bready Shop           15
# California 94114  Super River           25
# CA 94114           Ben's Shop           10
# California            Sanchez           12
# CA 94114           Richvalley           20
